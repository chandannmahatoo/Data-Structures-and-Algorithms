# %% [markdown]
# # Invert Binary Tree (#226)
# ## Problem Statement:
# Given the root of a binary tree, invert the tree, and return its root.
#
#
# ## Examples
# ### Example 1:
# ```Mermaid
# graph TD
#     subgraph Before
#         B4[4] --> B2[2]
#         B4 --> B7[7]
#         B2 --> B1[1]
#         B2 --> B3[3]
#         B7 --> B6[6]
#         B7 --> B9[9]
#     end
#
#     subgraph After
#         A4[4] --> A7[7]
#         A4 --> A2[2]
#         A7 --> A9[9]
#         A7 --> A6[6]
#         A2 --> A3[3]
#         A2 --> A1[1]
#     end
# ```
# **Input:** root = [4,2,7,1,3,6,9]
#
# **Output:** [4,7,2,9,6,3,1]
#
# ### Example 2:
# ```Mermaid
# graph TD
#     subgraph Before
#         B2[2] --> B1[1]
#         B2 --> B3[3]
#     end
#
#     subgraph After
#         A2[2] --> A3[3]
#         A2 --> A1[1]
#     end
# ```
# **Input:** root = [2,1,3]
#
# **Output:** [2,3,1]
#
# ### Example 3:
# **Input:** root = []
#
# **Output:** []
#
#
# ## Constraints:
# > The number of nodes in the tree is in the range [0, 100].
#
# > -100 <= Node.val <= 100

# %% [markdown]
# # What is a Binary Tree?
# A binary tree is a hierarchical data structure where each node has at most two children.
# - Left child
# - Right child
#  ```Mermaid
#  graph TD
#     subgraph Example
#         B4[4] --> B2[2]
#         B4 --> B7[7]
#         B2 --> B1[1]
#         B2 --> B3[3]
#         B7 --> B6[6]
#         B7 --> B9[9]
#     end
# ```
#
# # What does "Invert" mean?
# Invert a binary tree means swapping the left and right child of every node in tree.
# ```Mermaid
# graph TD
#     subgraph Original
#         B4[4] --> B2[2]
#         B4 --> B7[7]
#         B2 --> B1[1]
#         B2 --> B3[3]
#         B7 --> B6[6]
#         B7 --> B9[9]
#     end
#
#     subgraph Mirror
#         A4[4] --> A7[7]
#         A4 --> A2[2]
#         A7 --> A9[9]
#         A7 --> A6[6]
#         A2 --> A3[3]
#         A2 --> A1[1]
#     end
# ```
#
# **Notice:**
# | Original | Inverted |
# |----------|----------|
# | Left subtree | Right subtree |
# | Right subtree | Left subtree |
# | 2 becomes left child | 2 becomes right child |
# | 7 becomes right child | 7 becomes left child |
#
# Every node has its children exchanged.

# %% [markdown]
# # Solutin of the Problem:

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def invertTree(self, root):
        if root is None:
            return None

        root.left, root.right = root.right, root.left

        self.invertTree(root.left)
        self.invertTree(root.right)

        return root

# %%
from collections import deque

# Helper function to convert tree to list (Level Order)
def level_order(root):
    if root is None:
        return []

    result = []
    queue = deque([root])

    while queue:
        node = queue.popleft()

        if node:
            result.append(node.val)
            queue.append(node.left)
            queue.append(node.right)
        else:
            result.append(None)

    # Remove unnecessary trailing None values
    while result and result[-1] is None:
        result.pop()

    return result

# %% [markdown]
# # Test Cases:

# %%
solution = Solution()

tree = None

print("Test Case 1")
print("Input: ", level_order(tree))

result = solution.invertTree(tree)

print("Output:", level_order(result))
# Out:
# Test Case 1
# Input:  []
# Output: []

# %%
tree = TreeNode(1)

print("Test Case 2")
print("Input: ", level_order(tree))

result = solution.invertTree(tree)

print("Output:", level_order(result))
# Out:
# Test Case 2
# Input:  [1]
# Output: [1]

# %%
tree = TreeNode(1)
tree.left = TreeNode(2)
tree.right = TreeNode(3)

print("Test Case 3")
print("Input: ", level_order(tree))

result = solution.invertTree(tree)

print("Output:", level_order(result))
# Out:
# Test Case 3
# Input:  [1, 2, 3]
# Output: [1, 3, 2]

# %%
tree = TreeNode(4)

tree.left = TreeNode(2)
tree.right = TreeNode(7)

tree.left.left = TreeNode(1)
tree.left.right = TreeNode(3)

tree.right.left = TreeNode(6)
tree.right.right = TreeNode(9)

print("Test Case 4")
print("Input: ", level_order(tree))

result = solution.invertTree(tree)

print("Output:", level_order(result))
# Out:
# Test Case 4
# Input:  [4, 2, 7, 1, 3, 6, 9]
# Output: [4, 7, 2, 9, 6, 3, 1]

# %%
tree = TreeNode(1)
tree.left = TreeNode(2)
tree.left.left = TreeNode(3)

print("Test Case 5")
print("Input: ", level_order(tree))

result = solution.invertTree(tree)

print("Output:", level_order(result))
# Out:
# Test Case 5
# Input:  [1, 2, None, 3]
# Output: [1, None, 2, None, 3]

# %%
tree = TreeNode(1)
tree.right = TreeNode(2)
tree.right.right = TreeNode(3)

print("Test Case 6")
print("Input: ", level_order(tree))

result = solution.invertTree(tree)

print("Output:", level_order(result))
# Out:
# Test Case 6
# Input:  [1, None, 2, None, 3]
# Output: [1, 2, None, 3]
